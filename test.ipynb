# %%
import pandas as pd
from DataUtil import *

# %%
df = pd.read_csv(r"C:\Users\ammar\OneDrive\Desktop\PracticeData\StudentPerformanceFactors.csv")

# %%
dt = DataTools(df)

# %%
def quick_test():
    """
    Quick sanity test for DataTools.
    Creates a small DataFrame and runs core methods once.
    """

    df = pd.DataFrame({
        "age": [20, 25, np.nan, 30, 30],
        "salary": [300, 400, 500, np.nan, 400],
        "dept": ["IT", "IT", "HR", "HR", "HR"],
        "name": [" Ali ", "ALI", "Sara!", "Omar", "Omar"]
    })

    print("=== Original Data ===")
    print(df)

    dt = DataTools(df)

    print("\n=== Overview ===")
    summary, info = dt.overview()
    print(summary)
    print(info)

    print("\n=== Fill Missing (median) ===")
    print(dt.fillMissingValues("median", inplace=False))

    print("\n=== Drop Duplicates (dept + salary) ===")
    print(dt.dropDuplicates(columns=["dept", "salary"], inplace=False))

    print("\n=== IQR Outliers ===")
    print(dt.detect_outliers_iqr())

    print("\n=== Z-score Outliers ===")
    print(dt.detect_outliers_zscore())

    print("\n=== Encoding (One-Hot) ===")
    print(dt.oneHotEncode(inplace=False))

    print("\n=== Scaling (standard) ===")
    print(dt.scale("standard", inplace=False))

    print("\n=== Feature Combination ===")
    print(dt.combineFeatures("double_salary", "salary * 2", inplace=False))

    print("\n=== Text Cleaning ===")
    print(dt.cleanText(["name"], remove_punct=True, inplace=False))

    print("\n=== TEST COMPLETED SUCCESSFULLY ===")

# %%
# Out:
# === Original Data ===
#     age  salary dept   name
# 0  20.0   300.0   IT   Ali
# 1  25.0   400.0   IT    ALI
# 2   NaN   500.0   HR  Sara!
# 3  30.0     NaN   HR   Omar
# 4  30.0   400.0   HR   Omar
#
# === Overview ===
# {'rows': 5, 'cols': 4, 'duplicates': 0, 'memory_MB': 0.0007753372192382812}
#           dtype  missing_%  missing_count  unique
# age     float64       20.0              1       3
# salary  float64       20.0              1       3
# dept     object        0.0              0       2
# name     object        0.0              0       4
#
# === Fill Missing (median) ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 quick_test()
#
# Cell In[54], line 25, in quick_test()
#      22 print(info)
#      24 print("\n=== Fill Missing (median) ===")
# ---> 25 print(dt.fillMissingValues("median", inplace=False))
#      27 print("\n=== Drop Duplicates (dept + salary) ===")
#      28 print(dt.dropDuplicates(columns=["dept", "salary"], inplace=False))
#
# AttributeError: 'DataTools' object has no attribute 'fillMissingValues'
