# %%
import pandas as pd
from DataUtil import DataTools as df, DataTools

# %%
dataFrame = pd.read_csv(r"C:\Users\ammar\OneDrive\Desktop\PracticeData\StudentPerformanceFactors.csv")

# %%
df = DataTools(dataFrame)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.head()
#
# AttributeError: 'DataTools' object has no attribute 'head'
